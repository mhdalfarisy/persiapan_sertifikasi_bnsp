# %% [markdown]
# 🎯 DATA AWAL (Sebelum Feature Engineering)
# Gender	ContractType	CustomerLevel	Tenure	MonthlyCharges	Churn
# Male	Month-to-month	Bronze	5	70.35	Yes
# Female	One year	Silver	24	99.20	No
# Female	Two year	Gold	36	60.10	No
#
# Sekarang kita lihat perubahan berdasarkan skala datanya.
#
# 🔵 1️⃣ NOMINAL → One Hot Encoding
# Kolom:
#
# ContractType
#
# Gender (binary bisa label juga)
#
# 🔹 Sebelum
# ContractType
# Month-to-month
# One year
# Two year
# 🔹 Sesudah One Hot
# Contract_OneYear	Contract_TwoYear
# 0	0
# 1	0
# 0	1
#
# Month-to-month jadi baseline (karena drop_first=True).
#
# 📌 Hasil:
#
# Jumlah kolom bertambah
#
# Tidak ada urutan
#
# Semua angka 0/1
#
# 🟠 2️⃣ ORDINAL → Mapping / Ordinal Encoding
# Kolom:
#
# CustomerLevel
#
# Bronze < Silver < Gold
#
# 🔹 Sebelum
# CustomerLevel
# Bronze
# Silver
# Gold
# 🔹 Setelah Mapping
# CustomerLevel
# 1
# 2
# 3
#
# 📌 Hasil:
#
# Tetap 1 kolom
#
# Ada urutan numerik
#
# Model bisa membaca ranking
#
# 🟡 3️⃣ INTERVAL → Scaling
#
# Contoh interval:
# Year = 2000, 2010, 2020
#
# 🔹 Sebelum
# Year
# 2000
# 2010
# 2020
# 🔹 Setelah StandardScaler
# Year_scaled
# -1.22
# 0.00
# 1.22
#
# 📌 Hasil:
#
# Rata-rata jadi 0
#
# Skala seragam
#
# Model linear lebih stabil
#
# 🟢 4️⃣ RASIO → Scaling / Transformasi
#
# Contoh:
# MonthlyCharges
#
# 🔹 Sebelum
# MonthlyCharges
# 70.35
# 99.20
# 60.10
# 🔹 Setelah Scaling
# MonthlyCharges_scaled
# -0.85
# 1.23
# -1.10
# 🔹 Jika Log Transformation (kalau skewed)
# MonthlyCharges_log
# 4.25
# 4.60
# 4.10
# 🚀 HASIL FINAL SETELAH SEMUA FEATURE ENGINEERING
#
# Gabungkan semuanya:
#
# Gender	CustomerLevel	Tenure	MonthlyCharges_scaled	Contract_OneYear	Contract_TwoYear	Churn
# 1	1	5	-0.85	0	0	1
# 0	2	24	1.23	1	0	0
# 0	3	36	-1.10	0	1	0
#
# Sekarang:
#
# ✔ Tidak ada teks
# ✔ Semua numerik
# ✔ Siap modeling
# ✔ Tidak ada bias ordinal salah
#
# 🎯 Perubahan yang Terjadi
# Skala	Sebelum	Sesudah
# Nominal	1 kolom teks	Beberapa kolom 0/1
# Ordinal	Teks	Angka berurutan
# Interval	Angka besar	Angka terstandar
# Rasio	Angka mentah	Angka ter-scaled
# 🎤 Jawaban Siap Ujian
#
# Jika ditanya:
#
# "Bagaimana gambaran hasil feature engineering?"
#
# Jawaban:
#
# Setelah feature engineering, seluruh variabel kategorikal telah dikonversi menjadi numerik menggunakan One Hot Encoding untuk nominal dan mapping untuk ordinal. Variabel numerikal interval dan rasio telah dilakukan scaling sehingga dataset akhir seluruhnya numerik dan siap digunakan untuk proses modeling.
